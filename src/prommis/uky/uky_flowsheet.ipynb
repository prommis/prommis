# %% [markdown]
# # UKy Flowsheet tutorial:
#
# This tutorial will show how to build, initialize, and simulate the West Kentucky No.13 Coal Refuse flowsheet.
#
# - Useful Links:
#     - Public Github Repository: https://github.com/prommis/prommis/tree/main
#     - UKy Flowsheet Code: https://github.com/prommis/prommis/blob/main/src/prommis/uky/uky_flowsheet.py
#
# <img src="uky_flowsheet.png" width="1000" height="680">

# %% [markdown]
# ## Step 1: Import the necessary tools

# %%
# Import the essentials from Pyomo
from pyomo.environ import (
    ConcreteModel,
    Constraint,
    SolverFactory,
    Suffix,
    TransformationFactory,
    Var,
    units,
)
from pyomo.network import Arc, SequentialDecomposition
from pyomo.util.check_units import assert_units_consistent

# Import the essentials from IDAES
from idaes.models.properties.modular_properties.base.generic_property import (
    GenericParameterBlock,
)
from idaes.models_extra.power_generation.properties.natural_gas_PR import (
    EosType,
    get_prop,
)
from idaes.core import (
    FlowDirection,
    FlowsheetBlock,
    MaterialBalanceType,
    MomentumBalanceType,
)

# Import initializtion and diagnostic tools from IDAES
from idaes.core.initialization import BlockTriangularizationInitializer
from idaes.core.util.initialization import propagate_state
from idaes.core.util.model_diagnostics import DiagnosticsToolbox
from idaes.core.util.model_statistics import degrees_of_freedom

# Import unit models from IDAES
from idaes.models.unit_models.feed import Feed, FeedInitializer
from idaes.models.unit_models.mixer import Mixer, MixingType, MomentumMixingType
from idaes.models.unit_models.mscontactor import MSContactor, MSContactorInitializer
from idaes.models.unit_models.product import Product, ProductInitializer
from idaes.models.unit_models.separator import (
    EnergySplittingType,
    Separator,
    SplittingType,
)
from idaes.models.unit_models.solid_liquid import SLSeparator

# Import the UKy-specific unit and property models
from prommis.leaching.leach_reactions import CoalRefuseLeachingReactions
from prommis.leaching.leach_solids_properties import CoalRefuseParameters
from prommis.leaching.leach_solution_properties import LeachSolutionParameters
from prommis.precipitate.precipitate_liquid_properties import AqueousParameter
from prommis.precipitate.precipitate_solids_properties import PrecipitateParameters
from prommis.precipitate.precipitator import Precipitator
from prommis.roasting.ree_oxalate_roaster import REEOxalateRoaster
from prommis.solvent_extraction.ree_aq_distribution import REESolExAqParameters
from prommis.solvent_extraction.ree_og_distribution import REESolExOgParameters
from prommis.solvent_extraction.solvent_extraction import SolventExtraction

# %% [markdown]
# ## Step 2 Flowsheet building

# %% [markdown]
# ### Step 2.1: Create Flowsheet
# Start by creating a pyomo model and a flowsheet.

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(dynamic=False)

# %% [markdown]
# Then begin assembling the unit, property, and reaction models section-by-section. These variables will be created in chronological order - beginning with the leaching section of the flowsheet and concluding with the product roasting section.

# %% [markdown]
# ### Step 2.2 Create variables for the leaching section

# %%
# Leaching property models
m.fs.leach_soln = LeachSolutionParameters()
m.fs.coal = CoalRefuseParameters()

# Leaching reaction model
m.fs.leach_rxns = CoalRefuseLeachingReactions()

# Leaching unit model
m.fs.leach = MSContactor(
    number_of_finite_elements=2,
    streams={
        "liquid": {
            "property_package": m.fs.leach_soln,
            "has_energy_balance": False,
            "has_pressure_balance": False,
        },
        "solid": {
            "property_package": m.fs.coal,
            "has_energy_balance": False,
            "has_pressure_balance": False,
        },
    },
    heterogeneous_reactions=m.fs.leach_rxns,
)

m.fs.leach.volume = Var(
m.fs.time,
m.fs.leach.elements,
initialize=1,
units=units.litre,
doc="Volume of each finite element.",
)

# Define constraint for heterogeneous reaction extent
def rule_heterogeneous_reaction_extent(b, t, s, r):
    return (
        b.heterogeneous_reaction_extent[t, s, r]
        == b.heterogeneous_reactions[t, s].reaction_rate[r] * b.volume[t, s]
        )

m.fs.leach.heterogeneous_reaction_extent_constraint = Constraint(
    m.fs.time,
    m.fs.leach.elements,
    m.fs.leach_rxns.reaction_idx,
    rule=rule_heterogeneous_reaction_extent,
)

# Solid-liquid separator used to approximate a filter press
m.fs.sl_sep1 = SLSeparator(
    solid_property_package=m.fs.coal,
    liquid_property_package=m.fs.leach_soln,
    material_balance_type=MaterialBalanceType.componentTotal,
    # Ignore momentum balance since the property package does not have pressure or momentum terms
    momentum_balance_type=MomentumBalanceType.none,
    # Ignore energy split basis since the property package does not have temperature terms
    energy_split_basis=EnergySplittingType.none,
)

# Recycle loop mixer
m.fs.leach_mixer = Mixer(
    property_package=m.fs.leach_soln,
    num_inlets=2,
    inlet_list=["recycle", "feed"],
    material_balance_type=MaterialBalanceType.componentTotal,
    # Ignore mixing type since the property package does not have enthalpy terms
    energy_mixing_type=MixingType.none,
    # Ignore momentum mixing since the property package does not have pressure or momentum terms
    momentum_mixing_type=MomentumMixingType.none,
)

# Define inlets into the flowsheet
m.fs.leach_liquid_feed = Feed(property_package=m.fs.leach_soln)
m.fs.leach_solid_feed = Feed(property_package=m.fs.coal)

# Define outlets from the flowsheet
m.fs.leach_filter_cake = Product(property_package=m.fs.coal)
m.fs.leach_filter_cake_liquid = Product(property_package=m.fs.leach_soln)

# %% [markdown]
# ### Step 2.3 Create variables for the solvent extraction section

# %%
# Solvent extraction property models
m.fs.prop_a = REESolExAqParameters()
m.fs.prop_o = REESolExOgParameters()

# First unit model in the solvent extraction circuit (cleaner defined in the precipitation section)
m.fs.solex_rougher = SolventExtraction(
    number_of_finite_elements=3,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
)

# Recycle loop separator
m.fs.sep1 = Separator(
    property_package=m.fs.leach_soln,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

# Mixes the solvent extraction outlet streams prior to feeding to the precipitator
m.fs.sx_mixer = Mixer(
    property_package=m.fs.prop_o,
    num_inlets=2,
    inlet_list=["aqueous_inlet", "organic_inlet"],
    material_balance_type=MaterialBalanceType.componentTotal,
    energy_mixing_type=MixingType.none,
    momentum_mixing_type=MomentumMixingType.none,
)

# Define outlets from the flowsheet
m.fs.recycle1_purge = Product(property_package=m.fs.leach_soln)

# %% [markdown]
# ### Step 2.3 Create variables for the precipitation section

# %%
# Need to define the set of key ions
key_components = {
    "H^+",
    "Ce^3+",
    "Al^3+",
    "Fe^3+",
    "Ca^2+",
    "C2O4^2-",
}

# Precipitation property packages
m.fs.properties_aq = AqueousParameter()
m.fs.properties_solid = PrecipitateParameters()

# Second unit model in the solvent extraction circuit - requires the aqueous precipitation package
m.fs.solex_cleaner = SolventExtraction(
    number_of_finite_elements=3,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.properties_aq,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
)

# Precipitation unit model
m.fs.precipitator = Precipitator(
    property_package_aqueous=m.fs.properties_aq,
    property_package_precipitate=m.fs.properties_solid,
)

# Solid-liquid separator used to approximate a filter press
m.fs.sl_sep2 = SLSeparator(
    solid_property_package=m.fs.properties_solid,
    liquid_property_package=m.fs.properties_aq,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

# Recycle loop separator
m.fs.sep2 = Separator(
    property_package=m.fs.properties_aq,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

# Define outlets from the flowsheet
m.fs.recycle2_purge = Product(property_package=m.fs.properties_aq)

# %% [markdown]
# ### Step 2.3 Create variables for the product roaster section

# %%
# Define the relevant gas species
gas_species = {"O2", "H2O", "CO2", "N2"}

# Roaster property packages
m.fs.prop_gas = GenericParameterBlock(
    **get_prop(gas_species, ["Vap"], EosType.IDEAL),
    doc="gas property",
)
m.fs.prop_solid = PrecipitateParameters(
    key_components=key_components,
)

# Roaster unit model
m.fs.roaster = REEOxalateRoaster(
    property_package_gas=m.fs.prop_gas,
    property_package_precipitate=m.fs.prop_solid,
    has_holdup=False,
    has_heat_transfer=True,
    has_pressure_change=True,
)

# %% [markdown]
# ### Step 2.4 Connect the unit models
# Next, use Pyomo arcs as streams to connect the units as portrayed in the flowsheet image above.

# %%
m.fs.sol_feed = Arc(
    source=m.fs.leach_solid_feed.outlet, destination=m.fs.leach.solid_inlet
)
m.fs.liq_feed = Arc(
    source=m.fs.leach_liquid_feed.outlet, destination=m.fs.leach_mixer.feed
)
m.fs.feed_mixture = Arc(
    source=m.fs.leach_mixer.outlet, destination=m.fs.leach.liquid_inlet
)
m.fs.s01 = Arc(source=m.fs.leach.solid_outlet, destination=m.fs.sl_sep1.solid_inlet)
m.fs.s02 = Arc(
    source=m.fs.leach.liquid_outlet, destination=m.fs.sl_sep1.liquid_inlet
)
m.fs.sep1_solid = Arc(
    source=m.fs.sl_sep1.solid_outlet, destination=m.fs.leach_filter_cake.inlet
)
m.fs.sep1_retained_liquid = Arc(
    source=m.fs.sl_sep1.retained_liquid_outlet,
    destination=m.fs.leach_filter_cake_liquid.inlet,
)
m.fs.sep1_liquid = Arc(
    source=m.fs.sl_sep1.recovered_liquid_outlet,
    destination=m.fs.solex_rougher.mscontactor.aqueous_inlet,
)
m.fs.recycle1 = Arc(
    source=m.fs.solex_rougher.mscontactor.aqueous_outlet,
    destination=m.fs.sep1.inlet,
)
m.fs.purge1 = Arc(source=m.fs.sep1.purge, destination=m.fs.recycle1_purge.inlet)
m.fs.recycle_feed = Arc(
    source=m.fs.sep1.recycle, destination=m.fs.leach_mixer.recycle
)
m.fs.s03 = Arc(
    source=m.fs.solex_rougher.mscontactor.organic_outlet,
    destination=m.fs.solex_cleaner.mscontactor.organic_inlet,
)
m.fs.s04 = Arc(
    source=m.fs.solex_cleaner.mscontactor.aqueous_outlet,
    destination=m.fs.sx_mixer.aqueous_inlet,
)
m.fs.s05 = Arc(
    source=m.fs.solex_cleaner.mscontactor.organic_outlet,
    destination=m.fs.sx_mixer.organic_inlet,
)
m.fs.s06 = Arc(
    source=m.fs.sx_mixer.outlet,
    destination=m.fs.precipitator.aqueous_inlet,
)
m.fs.s07 = Arc(
    source=m.fs.precipitator.precipitate_outlet,
    destination=m.fs.sl_sep2.solid_inlet,
)
m.fs.s08 = Arc(
    source=m.fs.precipitator.aqueous_outlet, destination=m.fs.sl_sep2.liquid_inlet
)
m.fs.sep2_solid = Arc(
    source=m.fs.sl_sep2.solid_outlet, destination=m.fs.roaster.solid_inlet
)

m.fs.sep2_recovered_liquid = Arc(
    source=m.fs.sl_sep2.recovered_liquid_outlet, destination=m.fs.sep2.inlet
)
m.fs.purge2 = Arc(source=m.fs.sep2.purge, destination=m.fs.recycle2_purge.inlet)
m.fs.recycle2 = Arc(
    source=m.fs.sep2.recycle,
    destination=m.fs.solex_cleaner.mscontactor.aqueous_inlet,
)

TransformationFactory("network.expand_arcs").apply_to(m)

# %% [markdown]
# ### Step 2.5 Apply scaling
# In order for the flowsheet to solve, variables will need to be scaled appropriately. While variables often have a default scaling set, it is exceptionally important to re-scale those with poor initial scaling in this flowsheet as there are many trace components resulting in variables with  very small magnitudes.

# %%
def set_scaling():
    m.scaling_factor = Suffix(direction=Suffix.EXPORT)

    # Create a sets to target variables with these specfic components
    component_set1 = [
        "H2O",
        "H",
        "HSO4",
        "SO4",
        "Sc",
        "Y",
        "La",
        "Ce",
        "Pr",
        "Nd",
        "Sm",
        "Gd",
        "Dy",
        "Al",
        "Ca",
        "Fe",
    ]

    component_set2 = [
        "Sc",
        "Y",
        "La",
        "Ce",
        "Pr",
        "Nd",
        "Sm",
        "Gd",
        "Dy",
        "Al",
        "Ca",
        "Fe",
    ]

    # Apply scaling to badly scaled variables using the first component set
    for component in component_set1:
        m.scaling_factor[m.fs.leach.liquid[0, 1].conc_mol_comp[component]] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach_liquid_feed.properties[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sl_sep1.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sl_sep1.split.recovered_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sl_sep1.split.retained_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach_filter_cake_liquid.properties[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.aqueous[0, 1].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.aqueous[0, 2].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.aqueous[0, 3].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.aqueous_inlet_state[0].conc_mol_comp[
                component
            ]
        ] = 1e5
        m.scaling_factor[m.fs.sep1.mixed_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[m.fs.sep1.recycle_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[m.fs.sep1.purge_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[
            m.fs.recycle1_purge.properties[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach_mixer.recycle_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[m.fs.leach_mixer.feed_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[m.fs.leach_mixer.mixed_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5

    # Apply scaling to badly scaled variables using the second component set
    for component in component_set2:
        m.scaling_factor[
            m.fs.sl_sep2.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sl_sep2.split.recovered_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sl_sep2.split.retained_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.organic[0, 1].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.organic[0, 2].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.organic[0, 3].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mol_comp[
                component
            ]
        ] = 1e5
        m.scaling_factor[m.fs.sep2.mixed_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[m.fs.sep2.recycle_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[m.fs.sep2.purge_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[
            m.fs.recycle2_purge.properties[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.aqueous[0, 1].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.aqueous[0, 2].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.aqueous[0, 3].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.aqueous_inlet_state[0].conc_mol_comp[
                component
            ]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.organic[0, 1].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.organic[0, 2].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.organic[0, 3].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.solex_cleaner.mscontactor.organic_inlet_state[0].conc_mol_comp[
                component
            ]
        ] = 1e5
        m.scaling_factor[
            m.fs.sx_mixer.aqueous_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.sx_mixer.organic_inlet_state[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[m.fs.sx_mixer.mixed_state[0].conc_mol_comp[component]] = 1e5
        m.scaling_factor[
            m.fs.precipitator.cv_aqueous.properties_in[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.precipitator.cv_aqueous.properties_out[0].conc_mol_comp[component]
        ] = 1e5
        m.scaling_factor[
            m.fs.leach.liquid_inlet_state[0].conc_mol_comp[component]
        ] = 1e5

    # Apply scaling to the remaining badly scaled variables
    m.scaling_factor[m.fs.sl_sep2.solid_state[0].temperature] = 1e-2
    m.scaling_factor[m.fs.sl_sep2.liquid_inlet_state[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.sl_sep2.split.recovered_state[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.sl_sep2.split.retained_state[0].flow_vol] = 1e-2

    m.scaling_factor[m.fs.sep2.mixed_state[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.sep2.recycle_state[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.sep2.purge_state[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.recycle2_purge.properties[0].flow_vol] = 1e-2

    m.scaling_factor[m.fs.solex_cleaner.mscontactor.aqueous[0, 1].flow_vol] = 1e-2
    m.scaling_factor[m.fs.solex_cleaner.mscontactor.aqueous[0, 2].flow_vol] = 1e-2
    m.scaling_factor[m.fs.solex_cleaner.mscontactor.aqueous[0, 3].flow_vol] = 1e-2
    m.scaling_factor[
        m.fs.solex_cleaner.mscontactor.aqueous_inlet_state[0].flow_vol
    ] = 1e-2
    m.scaling_factor[m.fs.solex_cleaner.mscontactor.organic[0, 1].flow_vol] = 1e-2
    m.scaling_factor[m.fs.solex_cleaner.mscontactor.organic[0, 2].flow_vol] = 1e-2
    m.scaling_factor[m.fs.solex_cleaner.mscontactor.organic[0, 3].flow_vol] = 1e-2

    m.scaling_factor[
        m.fs.precipitator.cv_precipitate.properties_in[0].temperature
    ] = 1e2
    m.scaling_factor[
        m.fs.precipitator.cv_precipitate.properties_out[0].temperature
    ] = 1e-4

    m.scaling_factor[m.fs.precipitator.cv_aqueous.properties_in[0].flow_vol] = 1e-2
    m.scaling_factor[m.fs.precipitator.cv_aqueous.properties_out[0].flow_vol] = 1e-2

    m.scaling_factor[m.fs.roaster.gas_in[0].flow_mol] = 1e-3
    m.scaling_factor[m.fs.roaster.gas_in[0].flow_mol_phase["Vap"]] = 1e-3
    m.scaling_factor[m.fs.roaster.gas_in[0].temperature] = 1e-2
    m.scaling_factor[m.fs.roaster.gas_in[0].pressure] = 1e-5
    m.scaling_factor[m.fs.roaster.gas_out[0].flow_mol_phase["Vap"]] = 1e-3
    m.scaling_factor[m.fs.roaster.gas_out[0].flow_mol] = 1e-3
    m.scaling_factor[m.fs.roaster.gas_out[0].temperature] = 1e-2
    m.scaling_factor[m.fs.roaster.gas_out[0].pressure] = 1e-5
    m.scaling_factor[m.fs.roaster.solid_in[0].temperature] = 1e-2

    # Reassign m to use the new scaling factors
    scaling = TransformationFactory("core.scale_model")
    m = scaling.create_using(m, rename=False)

# %% [markdown]
# ### Step 2.6 Set the operating conditions

# %% [markdown]
# Now specify the inlet feed conditions into the flowsheet and fix any necessary unit model variables such that the
# degrees of freedom are equal to zero.

# %%
    eps = 1e-7 * units.mg / units.L

    # Fix the volume of the leaching tank
    m.fs.leach.volume.fix(100 * units.gallon)

    # Specify the flow rate and mass concentration of the liquid feed to the leaching unit
    m.fs.leach_liquid_feed.flow_vol.fix(224.3 * units.L / units.hour)
    m.fs.leach_liquid_feed.conc_mass_comp.fix(1e-10 * units.mg / units.L)
    m.fs.leach_liquid_feed.conc_mass_comp[0, "H"].fix(
        2 * 0.05 * 1e3 * units.mg / units.L
    )
    m.fs.leach_liquid_feed.conc_mass_comp[0, "HSO4"].fix(1e-8 * units.mg / units.L)
    m.fs.leach_liquid_feed.conc_mass_comp[0, "SO4"].fix(
        0.05 * 96e3 * units.mg / units.L
    )

    # Specify the mass flow and mass fractions of the solid feed to the leaching unit
    m.fs.leach_solid_feed.flow_mass.fix(22.68 * units.kg / units.hour)
    m.fs.leach_solid_feed.mass_frac_comp[0, "inerts"].fix(0.6952 * units.kg / units.kg)
    m.fs.leach_solid_feed.mass_frac_comp[0, "Al2O3"].fix(0.237 * units.kg / units.kg)
    m.fs.leach_solid_feed.mass_frac_comp[0, "Fe2O3"].fix(0.0642 * units.kg / units.kg)
    m.fs.leach_solid_feed.mass_frac_comp[0, "CaO"].fix(3.31e-3 * units.kg / units.kg)
    m.fs.leach_solid_feed.mass_frac_comp[0, "Sc2O3"].fix(
        2.77966e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Y2O3"].fix(
        3.28653e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "La2O3"].fix(
        6.77769e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Ce2O3"].fix(
        0.000156161 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Pr2O3"].fix(
        1.71438e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Nd2O3"].fix(
        6.76618e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Sm2O3"].fix(
        1.47926e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Gd2O3"].fix(
        1.0405e-05 * units.kg / units.kg
    )
    m.fs.leach_solid_feed.mass_frac_comp[0, "Dy2O3"].fix(
        7.54827e-06 * units.kg / units.kg
    )

    # Fix the flow rate and mass concentration of the organic inlet to the solvent extraction rougher
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].flow_vol.fix(
        62.01 * units.L / units.hour
    )
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Al"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Ca"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Fe"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Sc"].fix(
        321.34 * units.mg / units.L
    )
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Y"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["La"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Ce"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Pr"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Nd"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Sm"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Gd"].fix(eps)
    m.fs.solex_rougher.mscontactor.organic_inlet_state[0].conc_mass_comp["Dy"].fix(eps)

    # Fix the amount of liquid recovered from the two solid-liquid separators
    m.fs.sl_sep1.liquid_recovery.fix(0.7)   # 70% of liquid is recovered and 30% is retained in the filter cake
    m.fs.sl_sep2.liquid_recovery.fix(0.7)

    # Fix how much material is recycled in the two recycle loops
    m.fs.sep1.split_fraction[:, "recycle"].fix(0.9)   # 90% of the stream is recovered and 10% is purged
    m.fs.sep2.split_fraction[:, "recycle"].fix(0.9)

    # Fix the inlet temperature of the precipitator's precipitate inlet
    m.fs.precipitator.cv_precipitate.properties_in[0].temperature.fix(348.15 * units.K)
    m.fs.precipitator.cv_precipitate.properties_in[0].temperature.setlb(0)

    # Fix the operating conditions of the roaster
    m.fs.roaster.deltaP.fix(0)
    m.fs.roaster.gas_inlet.temperature.fix(1330)
    m.fs.roaster.gas_inlet.pressure.fix(101325)
    m.fs.roaster.solid_in[0].temperature.setlb(0)
    m.fs.roaster.gas_out[0].temperature.setub(2000)
    m.fs.roaster.gas_in[0].temperature.setub(2000)
    m.fs.roaster.gas_in[0].pressure.setub(1e6)

    fgas = 0.00781   # Inlet flue gas mole flow rate

    # Fix the inlet flue gas composition - typical flue gas by burning CH4 with air has a stoichiometric ratio of 2.3
    gas_comp = {
        "O2": 0.1118,
        "H2O": 0.1005,
        "CO2": 0.0431,
        "N2": 0.7446,
    }
    for i, v in gas_comp.items():
        m.fs.roaster.gas_inlet.mole_frac_comp[0, i].fix(v)
    m.fs.roaster.gas_inlet.flow_mol.fix(fgas)

    # Fix the outlet product temperature
    m.fs.roaster.gas_outlet.temperature.fix(873.15)

    # Fix the operating conditions
    m.fs.roaster.flow_mol_moist_feed.fix(6.75e-4)
    m.fs.roaster.frac_comp_recovery.fix(0.95)
# Out:
# WARNING (W1002): Setting Var
# 'fs.precipitator.cv_precipitate.properties_in[0.0].temperature' to a numeric
# value `348.15` outside the bounds (29814.999999999996, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.roaster.gas_in[0.0].temperature' to a numeric
# value `1330` outside the bounds (2.7315, 25.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.roaster.gas_in[0.0].pressure' to a numeric
# value `101325` outside the bounds (0.5, 1000.0000000000001).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002

# %% [markdown]
# # Step 3: Solve the square problem
# ## Step 3.1: Initialize the model

# %%
    # Initialize the model with sequential decomposition
    seq = SequentialDecomposition()
    seq.options.tear_method = "Direct"
    seq.options.iterLim = 1
    seq.options.tear_set = [m.fs.feed_mixture, m.fs.recycle2]

    # Print initialization order for user visibility
    G = seq.create_graph(m)
    order = seq.calculation_order(G)
    print("Initialization Order")
    for o in order:
        print(o[0].name)

    # Create tear guesses with initial guesses that are close to the solution
    tear_guesses1 = {
        "flow_mass": {0.007},
        "conc_mass_comp": {
            ("Al"): 1493939.39,
            ("Ca"): 501864.01,
            ("Ce"): 49698.79,
            ("Dy"): 466.86,
            ("Fe"): 1685228.86,
            ("Gd"): 1624.81,
            ("La"): 32143.22,
            ("Nd"): 12552.13,
            ("Pr"): 4084.40,
            ("Sc"): 17310.17,
            ("Sm"): 931.35,
            ("Y"): 2666.95,
        },
        "flow_mol_comp": {
            ("Al"): 577.62,
            ("Ca"): 64.65,
            ("Ce"): 1.17,
            ("Dy"): 0.0086,
            ("Fe"): 231.93,
            ("Gd"): 0.054,
            ("La"): 0.63,
            ("Nd"): 0.34,
            ("Pr"): 0.099,
            ("Sc"): 303.33,
            ("Sm"): 0.021,
            ("Y"): 0.090,
        },
    }
    tear_guesses2 = {
        "flow_mol_comp": {
            ("Al2(C2O4)3(s)"): 1.76,
            ("Ce2(C2O4)3(s)"): 2.65,
            ("Dy2(C2O4)3(s)"): 0.068,
            ("Fe2(C2O4)3(s)"): 2.64,
            ("Gd2(C2O4)3(s)"): 0.27,
            ("La2(C2O4)3(s)"): 0.86,
            ("Nd2(C2O4)3(s)"): 1.35,
            ("Pr2(C2O4)3(s)"): 0.36,
            ("Sc2(C2O4)3(s)"): 0.62,
            ("Sm2(C2O4)3(s)"): 0.15,
            ("Y2(C2O4)3(s)"): 0.31,
        },
    }
    tear_guesses3 = {
        "flow_vol": {0: 747.99},
        "conc_mass_comp": {
            (0, "Al"): 180.84,
            (0, "Ca"): 28.93,
            (0, "Ce"): 5.48,
            (0, "Dy"): 4.46e-11,
            (0, "Fe"): 269.98,
            (0, "Gd"): 2.60e-7,
            (0, "H"): 20.06,
            (0, "H2O"): 1000000,
            (0, "HSO4"): 963.06,
            (0, "La"): 0.0037,
            (0, "Nd"): 1.81e-7,
            (0, "Pr"): 3.65e-6,
            (0, "SO4"): 486.24,
            (0, "Sc"): 4.17e-11,
            (0, "Sm"): 6.30e-10,
            (0, "Y"): 7.18e-11,
        },
    }
    tear_guesses4 = {
        "flow_vol": {0: 157.14},
        "conc_mass_comp": {
            (0, "Al"): 380.67,
            (0, "Ca"): 122.97,
            (0, "Ce"): 5.67,
            (0, "Dy"): 0.15,
            (0, "Fe"): 741.24,
            (0, "Gd"): 0.56,
            (0, "H"): 2.274,
            (0, "H2O"): 1000000,
            (0, "HSO4"): 881.19,
            (0, "La"): 2.24,
            (0, "Nd"): 2.68,
            (0, "Pr"): 0.72,
            (0, "SO4"): 3924.07,
            (0, "Sc"): 0.10,
            (0, "Sm"): 0.30,
            (0, "Y"): 0.39,
        },
    }

    # Pass the tear guesses to the sequential decomposition tool
    seq.set_guesses_for(m.fs.precipitator.cv_aqueous.properties_out[0], tear_guesses1)
    seq.set_guesses_for(
        m.fs.precipitator.cv_precipitate.properties_out[0], tear_guesses2
    )
    seq.set_guesses_for(m.fs.leach.liquid_inlet, tear_guesses3)
    seq.set_guesses_for(m.fs.solex_rougher.mscontactor.aqueous_inlet, tear_guesses4)

    # Initialize each stream in the flowsheet
    def function(stream):
        initializer_feed = FeedInitializer()
        initializer_product = ProductInitializer()
        initializer1 = MSContactorInitializer()
        initializer2 = BlockTriangularizationInitializer()

        propagate_state(m.fs.liq_feed)
        propagate_state(m.fs.sol_feed)

        if stream == m.fs.leach_liquid_feed:
            initializer_feed.initialize(m.fs.leach_liquid_feed)
        elif stream == m.fs.leach_solid_feed:
            initializer_feed.initialize(m.fs.leach_solid_feed)
        elif stream == m.fs.leach_filter_cake:
            print(f"Initializing {stream}")
            initializer_product.initialize(m.fs.leach_filter_cake)
        elif stream == m.fs.leach:
            print(f"Initializing {stream}")
            try:
                initializer1.initialize(m.fs.leach)
            except:
                # Fix feed states
                m.fs.leach.liquid_inlet.flow_vol.fix()
                m.fs.leach.liquid_inlet.conc_mass_comp.fix()
                m.fs.leach.solid_inlet.flow_mass.fix()
                m.fs.leach.solid_inlet.mass_frac_comp.fix()
                # Re-solve leach unit
                solver = SolverFactory("ipopt")
                solver.solve(m.fs.leach, tee=True)
                # Unfix feed states
                m.fs.leach_liquid_feed.flow_vol.unfix()
                m.fs.leach.liquid_inlet.conc_mass_comp.unfix()
                m.fs.leach.solid_inlet.flow_mass.unfix()
                m.fs.leach.solid_inlet.mass_frac_comp.unfix()
        elif stream == m.fs.leach_mixer:
            initializer2.initialize(m.fs.leach_mixer)
        elif stream == m.fs.solex_rougher.mscontactor:
            print(f"Initializing {stream}")
            initializer2.initialize(m.fs.solex_rougher)
        elif stream == m.fs.solex_cleaner.mscontactor:
            print(f"Initializing {stream}")
            initializer2.initialize(m.fs.solex_cleaner)
        elif stream == m.fs.precipitator:
            print(f"Initializing {stream}")
            try:
                initializer2.initialize(m.fs.precipitator)
            except:
                # Fix feed states
                m.fs.precipitator.cv_precipitate.properties_in[0].temperature.setlb(0)
                m.fs.precipitator.cv_aqueous.properties_in[0].flow_vol.fix()
                m.fs.precipitator.cv_aqueous.properties_in[0].conc_mass_comp.fix()
                m.fs.precipitator.cv_precipitate.properties_in[0].flow_mol_comp.fix()
                # Re-solve precipitator unit
                solver = SolverFactory("ipopt")
                solver.solve(m.fs.precipitator, tee=True)
                # Unfix feed states
                m.fs.precipitator.cv_aqueous.properties_in[0].flow_vol.unfix()
                m.fs.precipitator.cv_aqueous.properties_in[0].conc_mass_comp.unfix()
                m.fs.precipitator.cv_precipitate.properties_in[0].flow_mol_comp.unfix()
        elif stream == m.fs.roaster:
            print(f"Initializing {stream}")
            try:
                initializer2.initialize(m.fs.roaster)
            except:
                m.fs.roaster.solid_in[0].temperature.setlb(0)
                m.fs.roaster.gas_out[0].temperature.setub(2000)
                m.fs.roaster.gas_in[0].temperature.setub(2000)
                m.fs.roaster.gas_in[0].pressure.setub(1e6)
                m.fs.roaster.gas_inlet.flow_mol.fix()
                m.fs.roaster.flow_mol_moist_feed.fix()
                m.fs.roaster.frac_comp_recovery.fix()
                # Re-solve roaster unit
                solver = SolverFactory("ipopt")
                solver.solve(m.fs.roaster, tee=True)
                m.fs.roaster.gas_inlet.flow_mol.unfix()
                m.fs.roaster.flow_mol_moist_feed.unfix()
                m.fs.roaster.frac_comp_recovery.unfix()
        else:
            print(f"Initializing {stream}")
            initializer2.initialize(stream)

    seq.run(m, function)
# Out:
# Initialization Order
# fs.leach_solid_feed
# fs.leach
# fs.sl_sep1
# fs.leach_filter_cake
# fs.sep1
# fs.sx_mixer
# fs.precipitator
# fs.sl_sep2
# fs.roaster
# fs.recycle2_purge
# Initializing fs.leach
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Sc]' to a
# numeric value `-6.939701540306167e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Sc]' to a
# numeric value `-1.5440760305548552e-12` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Y]' to a
# numeric value `-6.040794230186165e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Y]' to a
# numeric value `-6.794582393549828e-13` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Nd]' to a
# numeric value `-9.386044979863707e-10` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Nd]' to a
# numeric value `-6.507151366689276e-10` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Sm]' to a
# numeric value `-3.1340363027994148e-12` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Sm]' to a
# numeric value `-2.084289408028659e-12` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Gd]' to a
# numeric value `-1.236740222565469e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Gd]' to a
# numeric value `-7.864802961864262e-10` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Dy]' to a
# numeric value `-2.05294476107816e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Dy]' to a
# numeric value `-1.2639462126501778e-13` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Dy]' to a
# numeric value `4.099285014000578e-21` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# 2024-02-06 16:12:59 [INFO] idaes.init.fs.leach: Stream Initialization Completed.
# 2024-02-06 16:12:59 [INFO] idaes.init.fs.leach: Initialization Completed, optimal - Optimal Solution Found
# Initializing fs.sl_sep1
# Initializing fs.leach_filter_cake
# Initializing fs.leach_filter_cake_liquid
# Initializing fs.solex_rougher.mscontactor
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mass_comp[Sc]' to a numeric
# value `-2.802922401790568e-10` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mol_comp[Sc]' to a numeric
# value `-6.236199747861548e-10` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mass_comp[Y]' to a numeric
# value `-5.350034220450858e-10` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mol_comp[Y]' to a numeric
# value `-6.017698509166805e-10` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mass_comp[Sm]' to a numeric
# value `-2.481511819806752e-10` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mol_comp[Sm]' to a numeric
# value `-1.6503794577007313e-10` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mass_comp[Dy]' to a numeric
# value `-1.0774373442874768e-10` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mol_comp[Dy]' to a numeric
# value `-6.630402210178614e-11` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mass_comp[Nd]' to a numeric
# value `-1.3288232286640585e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mol_comp[Nd]' to a numeric
# value `-9.212455814492209e-10` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mol_comp[Sm]' to a numeric
# value `5.907012634345073e-16` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mass_comp[Gd]' to a numeric
# value `-1.563394316023775e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mol_comp[Gd]' to a numeric
# value `-9.94209413612631e-10` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,3].conc_mol_comp[Dy]' to a numeric
# value `2.7328566760003845e-16` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mass_comp[Y]' to a numeric
# value `-6.660019002551065e-11` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mol_comp[Y]' to a numeric
# value `-7.491161332154135e-11` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mass_comp[Sm]' to a numeric
# value `-4.037755393417642e-11` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mol_comp[Sm]' to a numeric
# value `-2.6854017812312e-11` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mass_comp[Dy]' to a numeric
# value `-3.781310288458034e-11` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.organic[0.0,3].conc_mol_comp[Dy]' to a numeric
# value `-2.3269591381974275e-11` outside the bounds (9.999999999999999e-16,
# None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Nd]' to
# a numeric value `-1.3288232286640585e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Gd]' to
# a numeric value `-1.563394316023775e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.sep1
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mass_comp[Sc]'
# to a numeric value `-3.424031439113262e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mol_comp[Sc]' to
# a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mass_comp[Y]' to
# a numeric value `-1.6698588471790943e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mol_comp[Y]' to
# a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mass_comp[Sm]'
# to a numeric value `-2.699488416780338e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mol_comp[Sm]' to
# a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mass_comp[Dy]'
# to a numeric value `-9.972120225571865e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.recycle_state[0.0].conc_mol_comp[Dy]' to
# a numeric value `1.366428338000192e-16` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mass_comp[Sc]' to
# a numeric value `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mol_comp[Sc]' to a
# numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mass_comp[Y]' to a
# numeric value `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mol_comp[Y]' to a
# numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mass_comp[Pr]' to
# a numeric value `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mol_comp[Pr]' to a
# numeric value `-2.0702741377527806e-09` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mass_comp[Sm]' to
# a numeric value `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mol_comp[Sm]' to a
# numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mass_comp[Dy]' to
# a numeric value `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.purge_state[0.0].conc_mol_comp[Dy]' to a
# numeric value `1.366428338000192e-16` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mol_comp[Nd]' to a
# numeric value `-9.212455814492209e-10` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mol_comp[Sm]' to a
# numeric value `5.907012634345073e-16` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mol_comp[Gd]' to a
# numeric value `-9.94209413612631e-10` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mol_comp[Dy]' to a
# numeric value `2.7328566760003845e-16` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Nd]' to
# a numeric value `-1.3288232286640585e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Gd]' to
# a numeric value `-1.563394316023775e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Nd]' to
# a numeric value `-1.3288232286640585e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sep1.mixed_state[0.0].conc_mass_comp[Gd]' to
# a numeric value `-1.563394316023775e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.424031439113262e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.6698588471790943e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.699488416780338e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-9.972120225571865e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.solex_cleaner.mscontactor
# Initializing fs.sx_mixer
# Initializing fs.recycle1_purge
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Sc]' to a numeric value
# `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Y]' to a numeric value `-0.0`
# outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Pr]' to a numeric value
# `-2.0702741377527806e-09` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Sm]' to a numeric value
# `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Dy]' to a numeric value
# `1.366428338000192e-16` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-4.990429271698837e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Sc]' to a numeric value
# `-1.1103218296823026e-12` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-2.5229167350761985e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Y]' to a numeric value
# `-2.8384645801394526e-13` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Nd]' to a numeric value
# `-1.6969187582190903e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Nd]' to a numeric value
# `-1.1760934967812695e-13` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-1.4917529407457293e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Sm]' to a numeric value
# `-9.909013694113859e-14` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Gd]' to a numeric value
# `-1.5668550826607535e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Gd]' to a numeric value
# `-9.969061435743851e-14` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.3803075629546154e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.mixed_state[0.0].conc_mol_comp[Dy]' to a numeric value
# `-8.5128485457412e-14` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mol_comp[Sc]' to a numeric value
# `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mol_comp[Y]' to a numeric value `-0.0`
# outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mol_comp[Sm]' to a numeric value
# `-0.0` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mol_comp[Dy]' to a numeric value
# `1.366428338000192e-16` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.424031439113262e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.6698588471790943e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.699488416780338e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-9.972120225571865e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.424031439113262e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.6698588471790943e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.699488416780338e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-9.972120225571865e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.precipitator
# WARNING (W1002): Setting Var
# 'fs.precipitator.cv_precipitate.properties_out[0.0].temperature' to a numeric
# value `0.0003481500000000039` outside the bounds (0.029814999999999998, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481500000000039` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.sl_sep2
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481500000000039` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481500000000039` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481500000000039` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.roaster
# WARNING (W1002): Setting Var 'fs.roaster.gas_out[0.0].pressure' to a numeric
# value `101325.0` outside the bounds (0.5, 1000.0000000000001).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       50
#
# Total number of variables............................:       74
#                      variables with only lower bounds:        2
#                 variables with lower and upper bounds:       16
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       74
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.45e+10 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.45e+10 9.70e+01  -1.0 1.00e+05    -  9.67e-03 9.86e-05h  1
#    2r 0.0000000e+00 3.45e+10 9.99e+02   7.0 0.00e+00    -  0.00e+00 4.93e-07R  2
#    3r 0.0000000e+00 6.91e+12 7.30e+05   7.0 1.33e+07    -  7.48e-04 6.21e-06f  1
#    4r 0.0000000e+00 6.88e+12 1.55e+05   3.5 2.13e+04    -  9.16e-01 4.47e-03f  1
#    5r 0.0000000e+00 2.64e+12 1.46e+05   3.5 1.09e+04    -  4.60e-01 9.07e-01f  1
#    6r 0.0000000e+00 4.02e+13 9.77e+04   3.5 1.35e+03    -  3.89e-01 8.96e-01f  1
#    7r 0.0000000e+00 2.62e+12 9.41e+04   3.5 1.03e-01   6.0 1.00e+00 1.00e+00f  1
#    8r 0.0000000e+00 4.35e+10 9.04e+03   2.8 1.43e-02   5.5 1.00e+00 1.00e+00f  1
#    9r 0.0000000e+00 1.00e+10 1.24e+03   2.1 1.12e-02   5.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 1
#   37r 0.0000000e+00 1.00e+10 3.53e+03   1.4 1.12e+00    -  1.00e+00 1.00e+00f  1
#   38r 0.0000000e+00 1.00e+10 7.49e+01   1.4 9.37e-01    -  1.00e+00 1.00e+00f  1
#   39r 0.0000000e+00 1.00e+10 5.62e+02  -0.7 4.53e+00    -  7.25e-01 7.38e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 0.0000000e+00 1.00e+10 2.84e+02  -0.7 3.05e+01    -  7.34e-01 9.10e-01f  1
#   41r 0.0000000e+00 1.00e+10 6.16e+01  -0.7 2.78e+01    -  1.00e+00 1.00e+00f  1
#   42r 0.0000000e+00 1.00e+10 9.79e-01  -0.7 4.69e-01    -  1.00e+00 1.00e+00f  1
#   43r 0.0000000e+00 1.00e+10 1.06e-01  -2.1 8.66e-01    -  1.00e+00 1.00e+00f  1
#   44r 0.0000000e+00 1.00e+10 1.88e-03  -3.1 1.44e+00    -  1.00e+00 1.00e+00f  1
#   45r 0.0000000e+00 1.00e+10 4.78e-02  -7.0 4.23e+00    -  1.00e+00 5.00e-01f  2
#   46r 0.0000000e+00 1.00e+10 4.97e-02  -7.0 4.95e+02    -  1.00e+00 5.00e-01f  2
#   47r 0.0000000e+00 1.00e+10 1.21e-01  -7.0 1.71e+02    -  1.00e+00 5.00e-01f  2
#   48r 0.0000000e+00 1.00e+10 2.02e-01  -7.0 2.72e+01    -  1.00e+00 5.00e-01f  2
#   49r 0.0000000e+00 1.00e+10 2.64e-01  -7.0 1.44e+02    -  1.00e+00 5.00e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r 0.0000000e+00 1.00e+10 2.65e-01  -7.0 1.78e+02    -  1.00e+00 5.00e-01f  2
#   51r 0.0000000e+00 1.00e+10 2.01e-01  -7.0 1.43e+02    -  1.00e+00 5.00e-01f  2
#   52r 0.0000000e+00 1.00e+10 1.20e-01  -7.0 8.76e+01    -  1.00e+00 5.00e-01f  2
#   53r 0.0000000e+00 1.00e+10 6.33e-02  -7.0 4.63e+01    -  1.00e+00 5.00e-01f  2
#   54r 0.0000000e+00 1.00e+10 3.19e-02  -7.0 2.34e+01    -  1.00e+00 5.00e-01f  2
#
# Number of Iterations....: 54
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   6.6316795289772582e-07    6.6316795289772582e-07
# Constraint violation....:   1.0032499998999998e+07    1.0032499998999998e+10
# Complementarity.........:   9.1716709076475246e-08    9.1716709076475246e-08
# Overall NLP error.......:   1.0032499998999998e+07    1.0032499998999998e+10
#
#
# Number of objective function evaluations             = 68
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 68
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 57
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.027
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="fs.roaster";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
# Initializing fs.sep2
# Initializing fs.recycle2_purge
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-4.990429271698837e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-2.5229167350761985e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Nd]' to a numeric value
# `-1.6969187582190903e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-1.4917529407457293e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Gd]' to a numeric value
# `-1.5668550826607535e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.3803075629546154e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.leach
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Sc]' to a
# numeric value `-4.990844612683202e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Sc]' to a
# numeric value `-1.1104144594233775e-12` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Y]' to a
# numeric value `-2.5178365242476794e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Y]' to a
# numeric value `-2.8320646105075936e-13` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Nd]' to a
# numeric value `-1.6554955964209516e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Nd]' to a
# numeric value `-1.1476147929979534e-13` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Sm]' to a
# numeric value `-1.4842797037296561e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Sm]' to a
# numeric value `-9.871633379787146e-14` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Gd]' to a
# numeric value `-1.554561400541162e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Gd]' to a
# numeric value `-9.886103594476152e-14` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mass_comp[Dy]' to a
# numeric value `-1.3827341648929908e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,1].conc_mol_comp[Dy]' to a
# numeric value `-8.509218970468385e-14` outside the bounds
# (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Sc]' to a
# numeric value `-4.990424307435501e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Sc]' to a
# numeric value `-1.1103063913921234e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Y]' to a
# numeric value `-2.5140953109872926e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Y]' to a
# numeric value `-2.8278499963597847e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Nd]' to a
# numeric value `-1.5224084979579807e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Nd]' to a
# numeric value `-1.0552514293763878e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Sm]' to a
# numeric value `-1.477893815128659e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Sm]' to a
# numeric value `-9.828715241115733e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Gd]' to a
# numeric value `-1.5611786412497758e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Gd]' to a
# numeric value `-9.926699984883749e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mass_comp[Dy]' to a
# numeric value `-1.3611116305012873e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.leach.liquid[0.0,2].conc_mol_comp[Dy]' to a
# numeric value `-8.376632720796806e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mol_comp[Nd]' to a numeric value
# `-1.1764387336006719e-13` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mol_comp[Sm]' to a numeric value
# `-2.1115476188625335e-10` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mol_comp[Gd]' to a numeric value
# `-9.964102276665745e-14` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mol_comp[Dy]' to a numeric value
# `-1.7291876910141622e-11` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# 2024-02-06 16:13:05 [INFO] idaes.init.fs.leach: Stream Initialization Completed.
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-4.990429271698837e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-2.5229167350761985e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Nd]' to a numeric value
# `-1.6969187582190903e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-1.4917529407457293e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Gd]' to a numeric value
# `-1.5668550826607535e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.3803075629546154e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# 2024-02-06 16:13:05 [INFO] idaes.init.fs.leach: Initialization Completed, optimal - Optimal Solution Found
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sc]' to a numeric value
# `-4.990429271698837e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Y]' to a numeric value
# `-2.5229167350761985e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Nd]' to a numeric value
# `-1.6969187582190903e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Sm]' to a numeric value
# `-1.4917529407457293e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Gd]' to a numeric value
# `-1.5668550826607535e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach.liquid_inlet_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.3803075629546154e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.sl_sep1
# Initializing fs.solex_rougher.mscontactor
# WARNING (W1002): Setting Var
# 'fs.solex_rougher.mscontactor.aqueous[0.0,2].conc_mass_comp[Sc]' to a numeric
# ...
# `-1.006708123483648e-17` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.leach_mixer.recycle_state[0.0].conc_mass_comp[Dy]' to a numeric value
# `-3.738921426392305e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Direct failed to converge in 1 iterations
# Initializing fs.leach_filter_cake
# Initializing fs.leach_filter_cake_liquid
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.recycle1_purge
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Pr]' to a numeric value
# `-2.0702740722639212e-09` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mol_comp[Dy]' to a numeric value
# `-8.550368357196288e-17` outside the bounds (9.999999999999999e-16, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sc]' to a numeric value
# `-3.795590487903628e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Y]' to a numeric value
# `-1.846509830198995e-18` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Pr]' to a numeric value
# `-2.917161113794452e-09` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Sm]' to a numeric value
# `-2.910542685311489e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.recycle1_purge.properties[0.0].conc_mass_comp[Dy]' to a numeric value
# `-1.0191244695079858e-19` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.solex_cleaner.mscontactor
# Initializing fs.sx_mixer
# Initializing fs.precipitator
# WARNING (W1002): Setting Var
# 'fs.precipitator.cv_precipitate.properties_out[0.0].temperature' to a numeric
# value `0.0003481499999613681` outside the bounds (0.029814999999999998, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481499999613681` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Initializing fs.sl_sep2
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481499999613681` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.sl_sep2.solid_state[0.0].temperature' to a
# numeric value `0.03481499999613681` outside the bounds (2.9815, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'fs
#
# Number of Iterations....: 54
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   6.6316795289772582e-07    6.6316795289772582e-07
# Constraint violation....:   1.0032499998999998e+07    1.0032499998999998e+10
# Complementarity.........:   9.1716709076475233e-08    9.1716709076475233e-08
# Overall NLP error.......:   1.0032499998999998e+07    1.0032499998999998e+10
#
#
# Number of objective function evaluations             = 68
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 68
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 57
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.026
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="fs.roaster";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
# Initializing fs.recycle2_purge

# %% [markdown]
# ## Step 3.2: Run solver
# Solve the model by running the flowsheet using the ipopt solver.

# %%
    solver = SolverFactory("ipopt")
    results = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     5442
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      858
#
# Total number of variables............................:     1987
#                      variables with only lower bounds:     1472
#                 variables with lower and upper bounds:       17
#                      variables with only upper bounds:       78
# Total number of equality constraints.................:     1974
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.58e+11 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.58e+11 9.70e+01  -1.0 1.00e+05  -4.0 9.67e-03 9.86e-05h  1
#    2r 0.0000000e+00 1.58e+11 9.99e+02   7.0 0.00e+00  -4.5 0.00e+00 4.93e-07R  2
#    3r 0.0000000e+00 2.06e+14 7.20e+05   7.0 1.33e+07    -  7.47e-04 1.27e-05f  1
#    4r 0.0000000e+00 2.96e+12 5.81e+05   4.9 7.42e+00   4.0 8.87e-01 1.32e-01f  1
#    5r 0.0000000e+00 1.18e+13 1.21e+06   2.8 1.39e+05    -  2.31e-01 3.31e-02f  1
#    6r 0.0000000e+00 1.17e+13 2.52e+06   2.8 1.24e+01   3.5 4.55e-01 9.93e-03f  1
#    7r 0.0000000e+00 1.13e+13 1.48e+07   2.8 3.16e+02   3.0 9.08e-02 1.55e-02f  1
#    8r 0.0000000e+00 4.99e+11 1.06e+07   2.8 3.28e+02   2.6 9.95e-02 1.74e-01f  1
#    9r 0.0000000e+00 4.81e+11 1.21e+08   2.8 2.67e+02   3.9 1.81e-01 2.90e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 4.67e+11 4.99e+05   2.8 3.17e+03   3.4 1.17e-01 2.48e-02h  6
#   11r 0.0000000e+00 3.87e+11 3.23e+07   2.8 2.47e+02   2.9 5.05e-01 8.61e-01f  1
#   12r 0.0000000e+00 1.08e+11 1.16e+05   2.8 3.59e+01   3.4 2.25e-01 8.83e-01f  1
#   13r 0.0000000e+00 5.99e+10 3.51e+05   2.1 5.62e+00   2.9 9.90e-01 1.00e+00f  1
#   14r 0.0000000e+00 3.28e+10 7.22e+03   2.1 5.42e-02   5.1 1.00e+00 1.00e+00f  1
#   15r 0.0000000e+00 4.78e+10 3.83e+03   2.1 1.08e-02   5.6 1.00e+00 1.00e+00f  1
#   16r 0.0000000e+00 1.00e+10 3.58e+03   2.1 4.19e-03   6.0 1.00e+00 1.00e+00f  1
#   17r 0.0000000e+00 5.51e+11 1.24e+04   2.1 1.27e-02   5.5 8.61e-01 1.00e+00f  1
#   18r 0.0000000e+00 9.23e+11 7.60e+03   2.1 3.58e-02   5.0 1.00e+00 1.00e+00f  1
#   19r 0.0000000e+00 4.70e+11 3.61e+03   2.1 4.25e-02   4.5 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00
-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180r 0.0000000e+00 1.00e+10 2.42e+02  -7.0 5.81e+01  -5.9 1.00e+00 1.68e-01f  1
#  181r 0.0000000e+00 1.00e+10 1.80e+02  -7.0 2.66e+02    -  1.00e+00 2.58e-01f  1
#  182r 0.0000000e+00 1.00e+10 8.02e+00  -7.0 1.97e+02    -  1.00e+00 9.55e-01f  1
#  183r 0.0000000e+00 1.00e+10 6.18e-03  -7.0 8.55e+00    -  1.00e+00 1.00e+00h  1
#  184r 0.0000000e+00 1.00e+10 1.03e-07  -7.0 1.51e-03    -  1.00e+00 1.00e+00h  1
#  185r 0.0000000e+00 1.00e+10 1.01e+02  -9.0 1.19e-02    -  1.00e+00 6.59e-01f  1
#  186r 0.0000000e+00 1.00e+10 7.35e+01  -9.0 1.13e+02  -6.3 2.11e-01 2.39e-01f  1
#  187r 0.0000000e+00 1.00e+10 5.78e+01  -9.0 3.11e+02  -6.8 5.78e-01 4.57e-01f  1
# In iteration 187, 1 Slack too small, adjusting variable bound
#  188r 0.0000000e+00 1.00e+10 5.61e+01  -9.0 7.34e+02  -7.3 8.31e-01 6.84e-01f  1
# In iteration 188, 1 Slack too small, adjusting variable bound
#  189r 0.0000000e+00 1.00e+10 1.15e+02  -9.0 1.18e+03  -7.8 1.00e+00 7.23e-01f  1
# In iteration 189, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r 0.0000000e+00 1.00e+10 2.57e+02  -9.0 2.40e+03  -8.3 1.00e+00 4.07e-01f  1
# In iteration 190, 1 Slack too small, adjusting variable bound
#  191r 0.0000000e+00 1.00e+10 3.42e+02  -9.0 3.91e+03  -8.7 1.00e+00 1.60e-01f  1
# In iteration 191, 1 Slack too small, adjusting variable bound
#  192r 0.0000000e+00 1.00e+10 4.55e+02  -9.0 7.81e+03  -9.2 2.79e-01 4.76e-02f  1
# In iteration 192, 1 Slack too small, adjusting variable bound
#  193r 0.0000000e+00 1.00e+10 7.60e+02  -9.0 1.40e+03  -8.8 9.62e-01 8.79e-02f  1
# In iteration 193, 1 Slack too small, adjusting variable bound
#  194r 0.0000000e+00 1.00e+10 7.18e+02  -9.0 9.92e+03  -9.3 2.02e-01 7.72e-02f  1
# In iteration 194, 1 Slack too small, adjusting variable bound
#  195r 0.0000000e+00 1.00e+10 1.68e+02  -9.0 2.19e+02    -  9.65e-01 7.64e-01f  1
# In iteration 195, 1 Slack too small, adjusting variable bound
#  196r 0.0000000e+00 1.00e+10 1.83e+01  -9.0 3.67e+01    -  1.00e+00 9.91e-01f  1
# In iteration 196, 1 Slack too small, adjusting variable bound
#  197r 0.0000000e+00 1.00e+10 3.07e-01  -9.0 1.88e+00    -  1.00e+00 1.00e+00h  1
# In iteration 197, 1 Slack too small, adjusting variable bound
#  198r 0.0000000e+00 1.00e+10 3.34e-06  -9.0 1.95e-04    -  1.00e+00 1.00e+00h  1
# In iteration 198, 1 Slack too small, adjusting variable bound
#  199r 0.0000000e+00 1.00e+10 1.80e-01  -9.0 5.53e-05    -  1.00e+00 9.97e-01h  1
# In iteration 199, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200r 0.0000000e+00 1.00e+10 1.40e+03  -9.0 9.29e-03    -  1.63e-05 9.21e-04f  1
# In iteration 200, 1 Slack too small, adjusting variable bound
#  201r 0.0000000e+00 1.00e+10 2.33e+03  -9.0 6.23e-05    -  6.13e-02 2.62e-02f  1
# In iteration 201, 1 Slack too small, adjusting variable bound
#  202r 0.0000000e+00 1.00e+10 2.04e+03  -9.0 5.53e-05    -  4.52e-01 1.00e+00f  1
# In iteration 202, 1 Slack too small, adjusting variable bound
#  203r 0.0000000e+00 1.00e+10 2.16e+03  -9.0 5.53e-05    -  1.00e+00 2.55e-04h  1
# In iteration 203, 1 Slack too small, adjusting variable bound
#  204r 0.0000000e+00 1.00e+10 3.93e+03  -9.0 1.89e+00    -  4.04e-07 6.76e-06f  1
# In iteration 204, 1 Slack too small, adjusting variable bound
#  205r 0.0000000e+00 1.00e+10 3.93e+03  -9.0 2.45e-03    -  1.52e-02 5.23e-04f  1
# In iteration 205, 1 Slack too small, adjusting variable bound
#  206r 0.0000000e+00 1.00e+10 3.53e+03  -9.0 7.58e-04    -  3.72e-01 1.03e-01f  1
# In iteration 206, 1 Slack too small, adjusting variable bound
#  207r 0.0000000e+00 1.00e+10 2.33e+03  -9.0 6.70e-04    -  1.30e-01 3.39e-01f  1
# In iteration 207, 1 Slack too small, adjusting variable bound
#  208r 0.0000000e+00 1.00e+10 1.41e+03  -9.0 3.21e-04    -  1.00e+00 3.98e-01f  1
# In iteration 208, 1 Slack too small, adjusting variable bound
#  209r 0.0000000e+00 1.00e+10 1.81e+02  -9.0 2.24e-04    -  1.00e+00 8.72e-01f  1
# In iteration 209, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210r 0.0000000e+00 1.00e+10 1.37e+02  -9.0 7.66e-05    -  1.00e+00 6.01e-01f  1
# In iteration 210, 1 Slack too small, adjusting variable bound
#  211r 0.0000000e+00 1.00e+10 2.00e+03  -9.0 1.00e+01    -  4.82e-08 2.36e-06h  1
# In iteration 211, 1 Slack too small, adjusting variable bound
#  212r 0.0000000e+00 1.00e+10 2.00e+03  -9.0 1.94e-04    -  1.88e-01 2.74e-03f  1
# In iteration 212, 1 Slack too small, adjusting variable bound
#  213r 0.0000000e+00 1.00e+10 1.68e+03  -9.0 8.26e-05    -  1.00e+00 1.58e-01f  1
# In iteration 213, 1 Slack too small, adjusting variable bound
#  214r 0.0000000e+00 1.00e+10 5.69e+02  -9.0 6.25e-05    -  4.77e-01 6.61e-01f  1
# In iteration 214, 1 Slack too small, adjusting variable bound
#  215r 0.0000000e+00 1.00e+10 3.07e+02  -9.0 7.47e-05    -  1.00e+00 5.01e-01f  1
# In iteration 215, 1 Slack too small, adjusting variable bound
#  216r 0.0000000e+00 1.00e+10 1.63e+02  -9.0 5.53e-05    -  1.00e+00 6.04e-01f  1
# In iteration 216, 1 Slack too small, adjusting variable bound
#  217r 0.0000000e+00 1.00e+10 1.33e+02  -9.0 5.53e-05    -  1.00e+00 5.86e-01f  1
# In iteration 217, 1 Slack too small, adjusting variable bound
#  218r 0.0000000e+00 1.00e+10 7.56e+01  -9.0 5.53e-05    -  1.00e+00 7.18e-01f  1
# In iteration 218, 1 Slack too small, adjusting variable bound
#  219r 0.0000000e+00 1.00e+10 6.51e+01  -9.0 5.53e-05    -  1.00e+00 6.02e-01f  1
# In iteration 219, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220r 0.0000000e+00 1.00e+10 1.28e+03  -9.0 2.60e-02    -  3.54e-05 3.12e-04f  1
# In iteration 220, 1 Slack too small, adjusting variable bound
#  221r 0.0000000e+00 1.00e+10 1.29e+03  -9.0 5.53e-05    -  1.00e+00 4.41e-06f  1
# In iteration 221, 1 Slack too small, adjusting variable bound
#  222r 0.0000000e+00 1.00e+10 6.36e+02  -9.0 5.53e-05    -  1.00e+00 5.16e-01f  1
# In iteration 222, 1 Slack too small, adjusting variable bound
#  223r 0.0000000e+00 1.00e+10 8.36e-06  -9.0 5.53e-05    -  1.00e+00 1.00e+00f  1
# In iteration 223, 1 Slack too small, adjusting variable bound
#  224r 0.0000000e+00 1.00e+10 4.32e+01  -9.0 5.53e-05    -  1.00e+00 4.37e-01h  1
# In iteration 224, 1 Slack too small, adjusting variable bound
#  225r 0.0000000e+00 1.00e+10 3.15e+01  -9.0 5.53e-05    -  1.00e+00 5.75e-01f  1
# In iteration 225, 1 Slack too small, adjusting variable bound
#  226r 0.0000000e+00 1.00e+10 1.41e+03  -9.0 4.27e-01    -  8.10e-07 1.91e-05f  1
# In iteration 226, 1 Slack too small, adjusting variable bound
#  227r 0.0000000e+00 1.00e+10 1.41e+03  -9.0 5.53e-05    -  1.00e+00 1.82e-04f  1
# In iteration 227, 1 Slack too small, adjusting variable bound
#  228r 0.0000000e+00 1.00e+10 7.02e+02  -9.0 5.53e-05    -  1.00e+00 5.02e-01f  1
# In iteration 228, 1 Slack too small, adjusting variable bound
#  229r 0.0000000e+00 1.00e+10 2.81e+02  -9.0 5.53e-05    -  1.00e+00 6.03e-01f  1
# In iteration 229, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230r 0.0000000e+00 1.00e+10 1.25e+02  -9.0 5.53e-05    -  1.00e+00 5.82e-01f  1
# In iteration 230, 1 Slack too small, adjusting variable bound
#  231r 0.0000000e+00 1.00e+10 5.67e+01  -9.0 5.53e-05    -  1.00e+00 6.63e-01f  1
# In iteration 231, 1 Slack too small, adjusting variable bound
#  232r 0.0000000e+00 1.00e+10 5.90e+01  -9.0 5.53e-05    -  1.00e+00 5.91e-01f  1
# In iteration 232, 1 Slack too small, adjusting variable bound
#  233r 0.0000000e+00 1.00e+10 1.25e+03  -9.0 2.65e-02    -  3.42e-05 2.96e-04f  1
# In iteration 233, 1 Slack too small, adjusting variable bound
#  234r 0.0000000e+00 1.00e+10 1.27e+03  -9.0 5.53e-05    -  1.00e+00 4.58e-06f  1
# In iteration 234, 1 Slack too small, adjusting variable bound
#  235r 0.0000000e+00 1.00e+10 6.28e+02  -9.0 5.53e-05    -  1.00e+00 5.12e-01f  1
# In iteration 235, 1 Slack too small, adjusting variable bound
#  236r 0.0000000e+00 1.00e+10 7.21e-01  -9.0 5.53e-05    -  9.95e-01 1.00e+00f  1
# In iteration 236, 1 Slack too small, adjusting variable bound
#  237r 0.0000000e+00 1.00e+10 8.71e+01  -9.0 1.27e-02    -  1.00e+00 5.31e-09h  1
# In iteration 237, 1 Slack too small, adjusting variable bound
#  238r 0.0000000e+00 1.00e+10 2.76e+01  -9.0 5.53e-05    -  1.00e+00 6.64e-01f  1
# In iteration 238, 1 Slack too small, adjusting variable bound
#  239r 0.0000000e+00 1.00e+10 1.48e+03  -9.0 1.62e+00    -  1.35e-07 5.24e-06f  1
# In iteration 239, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240r 0.0000000e+00 1.00e+10 1.48e+03  -9.0 5.53e-05    -  7.75e-01 9.84e-04f  1
# In iteration 240, 1 Slack too small, adjusting variable bound
#  241r 0.0000000e+00 1.00e+10 8.32e+02  -9.0 5.53e-05    -  1.00e+00 4.37e-01f  1
# In iteration 241, 1 Slack too small, adjusting variable bound
#  242r 0.0000000e+00 1.00e+10 3.25e+02  -9.0 5.53e-05    -  1.00e+00 6.10e-01f  1
# In iteration 242, 1 Slack too small, adjusting variable bound
#  243r 0.0000000e+00 1.00e+10 1.39e+02  -9.0 5.53e-05    -  1.00e+00 5.81e-01f  1
# In iteration 243, 1 Slack too small, adjusting variable bound
#  244r 0.0000000e+00 1.00e+10 6.63e+01  -9.0 5.53e-05    -  1.00e+00 6.08e-01f  1
# In iteration 244, 1 Slack too small, adjusting variable bound
#  245r 0.0000000e+00 1.00e+10 4.43e+01  -9.0 5.53e-05    -  1.00e+00 5.84e-01f  1
# In iteration 245, 1 Slack too small, adjusting variable bound
#  246r 0.0000000e+00 1.00e+10 1.41e+03  -9.0 4.52e-01    -  8.45e-07 1.90e-05f  1
# In iteration 246, 1 Slack too small, adjusting variable bound
#  247r 0.0000000e+00 1.00e+10 1.41e+03  -9.0 5.53e-05    -  1.00e+00 1.73e-04f  1
# In iteration 247, 1 Slack too small, adjusting variable bound
#  248r 0.0000000e+00 1.00e+10 7.05e+02  -9.0 5.53e-05    -  1.00e+00 5.03e-01f  1
# In iteration 248, 1 Slack too small, adjusting variable bound
#  249r 0.0000000e+00 1.00e+10 2.76e+02  -9.0 5.53e-05    -  1.00e+00 6.13e-01f  1
# In iteration 249, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250r 0.0000000e+00 1.00e+10 1.30e+02  -9.0 5.53e-05    -  1.00e+00 5.84e-01f  1
# In iteration 250, 1 Slack too small, adjusting variable bound
#  251r 0.0000000e+00 1.00e+10 3.17e+01  -9.0 5.53e-05    -  1.00e+00 8.27e-01f  1
# In iteration 251, 1 Slack too small, adjusting variable bound
#  252r 0.0000000e+00 1.00e+10 4.22e+01  -9.0 5.53e-05    -  1.00e+00 6.09e-01f  1
# In iteration 252, 1 Slack too small, adjusting variable bound
#  253r 0.0000000e+00 1.00e+10 1.26e+03  -9.0 3.40e-02    -  2.38e-05 2.32e-04f  1
# In iteration 253, 1 Slack too small, adjusting variable bound
#  254r 0.0000000e+00 1.00e+10 1.27e+03  -9.0 5.53e-05    -  1.00e+00 6.42e-06f  1
# In iteration 254, 1 Slack too small, adjusting variable bound
#  255r 0.0000000e+00 1.00e+10 6.32e+02  -9.0 5.53e-05    -  1.00e+00 5.11e-01f  1
# In iteration 255, 1 Slack too small, adjusting variable bound
#  256r 0.0000000e+00 1.00e+10 2.59e+02  -9.0 5.53e-05    -  1.00e+00 6.13e-01f  1
# In iteration 256, 1 Slack too small, adjusting variable bound
#  257r 0.0000000e+00 1.00e+10 1.52e+02  -9.0 5.53e-05    -  1.00e+00 5.91e-01f  1
# In iteration 257, 1 Slack too small, adjusting variable bound
#  258r 0.0000000e+00 1.00e+10 1.44e+03  -9.0 4.72e-02    -  2.16e-05 2.03e-04f  1
# In iteration 258, 1 Slack too small, adjusting variable bound
#  259r 0.0000000e+00 1.00e+10 1.45e+03  -9.0 5.53e-05    -  1.00e+00 7.29e-06f  1
# In iteration 259, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260r 0.0000000e+00 1.00e+10 7.13e+02  -9.0 5.53e-05    -  1.00e+00 5.15e-01f  1
# In iteration 260, 1 Slack too small, adjusting variable bound
#  261r 0.0000000e+00 1.00e+10 1.02e-05  -9.0 5.53e-05    -  1.00e+00 1.00e+00f  1
# In iteration 261, 1 Slack too small, adjusting variable bound
#  262r 0.0000000e+00 1.00e+10 1.79e+01  -9.0 5.53e-05    -  1.00e+00 7.95e-01h  1
# In iteration 262, 1 Slack too small, adjusting variable bound
#  263r 0.0000000e+00 1.00e+10 1.35e+03  -9.0 9.86e-02    -  5.07e-06 8.37e-05f  1
# In iteration 263, 1 Slack too small, adjusting variable bound
#  264r 0.0000000e+00 1.00e+10 1.36e+03  -9.0 5.53e-05    -  1.00e+00 2.23e-05f  1
# In iteration 264, 1 Slack too small, adjusting variable bound
#  265r 0.0000000e+00 1.00e+10 6.73e+02  -9.0 5.53e-05    -  1.00e+00 5.07e-01f  1
# In iteration 265, 1 Slack too small, adjusting variable bound
#  266r 0.0000000e+00 1.00e+10 2.75e+02  -9.0 5.53e-05    -  1.00e+00 6.03e-01f  1
# In iteration 266, 1 Slack too small, adjusting variable bound
#  267r 0.0000000e+00 1.00e+10 1.40e+02  -9.0 5.53e-05    -  1.00e+00 5.83e-01f  1
# In iteration 267, 1 Slack too small, adjusting variable bound
#  268r 0.0000000e+00 1.00e+10 1.56e+03  -9.0 4.71e-01    -  1.13e-06 2.18e-05f  1
# In iteration 268, 1 Slack too small, adjusting variable bound
#  269r 0.0000000e+00 1.00e+10 1.56e+03  -9.0 5.53e-05    -  8.54e-01 1.32e-04f  1
# In iteration 269, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270r 0.0000000e+00 1.00e+10 8.41e+02  -9.0 5.53e-05    -  1.00e+00 4.63e-01f  1
# In iteration 270, 1 Slack too small, adjusting variable bound
#  271r 0.0000000e+00 1.00e+10 3.34e+02  -9.0 5.53e-05    -  1.00e+00 6.07e-01f  1
# In iteration 271, 1 Slack too small, adjusting variable bound
#  272r 0.0000000e+00 1.00e+10 1.52e+02  -9.0 5.53e-05    -  1.00e+00 5.81e-01f  1
# In iteration 272, 1 Slack too small, adjusting variable bound
#  273r 0.0000000e+00 1.00e+10 1.64e+03  -9.0 4.35e+00    -  6.80e-08 2.42e-06h  1
# In iteration 273, 1 Slack too small, adjusting variable bound
#  274r 0.0000000e+00 1.00e+10 1.64e+03  -9.0 5.53e-05    -  7.55e-01 2.04e-03f  1
# In iteration 274, 1 Slack too small, adjusting variable bound
#  275r 0.0000000e+00 1.00e+10 9.33e+02  -9.0 5.53e-05    -  1.00e+00 4.31e-01f  1
# In iteration 275, 1 Slack too small, adjusting variable bound
#  276r 0.0000000e+00 1.00e+10 3.64e+02  -9.0 5.53e-05    -  1.00e+00 6.11e-01f  1
# In iteration 276, 1 Slack too small, adjusting variable bound
#  277r 0.0000000e+00 1.00e+10 1.58e+02  -9.0 5.53e-05    -  1.00e+00 5.81e-01f  1
# In iteration 277, 1 Slack too small, adjusting variable bound
#  278r 0.0000000e+00 1.00e+10 7.09e+01  -9.0 5.53e-05    -  1.00e+00 6.36e-01f  1
# In iteration 278, 1 Slack too small, adjusting variable bound
#  279r 0.0000000e+00 1.00e+10 5.04e+01  -9.0 5.53e-05    -  1.00e+00 5.88e-01f  1
# In iteration 279, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280r 0.0000000e+00 1.00e+10 1.42e+03  -9.0 3.57e-01    -  1.17e-06 2.44e-05f  1
# In iteration 280, 1 Slack too small, adjusting variable bound
#  281r 0.0000000e+00 1.00e+10 1.42e+03  -9.0 5.53e-05    -  1.00e+00 1.25e-04f  1
# In iteration 281, 1 Slack too small, adjusting variable bound
#  282r 0.0000000e+00 1.00e+10 7.07e+02  -9.0 5.53e-05    -  1.00e+00 5.03e-01f  1
# In iteration 282, 1 Slack too small, adjusting variable bound
#  283r 0.0000000e+00 1.00e+10 2.73e+02  -9.0 5.53e-05    -  1.00e+00 6.18e-01f  1
# In iteration 283, 1 Slack too small, adjusting variable bound
#  284r 0.0000000e+00 1.00e+10 1.27e+02  -9.0 5.53e-05    -  1.00e+00 5.84e-01f  1
# In iteration 284, 1 Slack too small, adjusting variable bound
#  285r 0.0000000e+00 1.00e+10 1.59e-07  -9.0 5.53e-05    -  1.00e+00 1.00e+00f  1
# In iteration 285, 1 Slack too small, adjusting variable bound
#  286r 0.0000000e+00 1.00e+10 4.72e+01  -9.0 5.53e-05    -  1.00e+00 8.11e-01h  1
# In iteration 286, 1 Slack too small, adjusting variable bound
#  287r 0.0000000e+00 1.00e+10 1.71e+02  -9.0 5.53e-05    -  1.00e+00 4.28e-01f  1
# In iteration 287, 1 Slack too small, adjusting variable bound
#  288r 0.0000000e+00 1.00e+10 9.68e+01  -9.0 5.53e-05    -  1.00e+00 7.97e-01f  1
# In iteration 288, 1 Slack too small, adjusting variable bound
#  289r 0.0000000e+00 1.00e+10 7.61e-08  -9.0 5.53e-05    -  1.00e+00 1.00e+00f  1
# In iteration 289, 1 Slack too small, adjusting variable bound
#
# Number of Iterations....: 289
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   8.8845894749874812e-05    8.8845894749874812e-05
# Constraint violation....:   1.0032499998999998e+07    1.0032499998999998e+10
# Complementarity.........:   1.8189894217356955e-04    1.8189894217356955e-04
# Overall NLP error.......:   1.0032499998999998e+07    1.0032499998999998e+10
#
#
# Number of objective function evaluations             = 337
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 337
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 292
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 290
# Total CPU secs in IPOPT (w/o function evaluations)   =      2.374
# Total CPU secs in NLP function evaluations           =      0.170
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.13.2\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %% [markdown]
# ## Step 3.3: report solution
# Finally, report the solution for the roaster model.

# %%
m.fs.roaster.display()
# Out:
# Block fs.roaster
#
#   Variables:
#     _flow_mol_gas_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_in[...].component('flow_mol')
#         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#         0.0 :   0.0 : 0.00781002309039114 :  50.0 : False : False : NonNegativeReals
#     _mole_frac_comp_gas_inlet_ref : Size=4, Index=fs.roaster._mole_frac_comp_gas_inlet_ref_index, ReferenceTo=fs.roaster.gas_in[...].component('mole_frac_comp')[...]
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         (0.0, 'CO2') : 1e-20 : 0.0431 : 1.001 :  True :  True :  Reals
#         (0.0, 'H2O') : 1e-20 : 0.1005 : 1.001 :  True :  True :  Reals
#          (0.0, 'N2') : 1e-20 : 0.7446 : 1.001 :  True :  True :  Reals
#          (0.0, 'O2') : 1e-20 : 0.1118 : 1.001 :  True :  True :  Reals
#     _temperature_gas_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_in[...].component('temperature')
#         Key : Lower  : Value : Upper : Fixed : Stale : Domain
#         0.0 : 2.7315 :  1330 :  2000 :  True :  True : NonNegativeReals
#     _pressure_gas_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_in[...].component('pressure')
#         Key : Lower : Value  : Upper     : Fixed : Stale : Domain
#         0.0 :   0.5 : 101325 : 1000000.0 :  True :  True : NonNegativeReals
#     _flow_mol_gas_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_out[...].component('flow_mol')
#         Key : Lower : Value                : Upper : Fixed : Stale : Domain
#         0.0 :   0.0 : 0.007811385350495414 :  50.0 : False : False : NonNegativeReals
#     _mole_frac_comp_gas_outlet_ref : Size=4, Index=fs.roaster._mole_frac_comp_gas_outlet_ref_index, ReferenceTo=fs.roaster.gas_out[...].component('mole_frac_comp')[...]
#         Key          : Lower : Value               : Upper : Fixed : Stale : Domain
#         (0.0, 'CO2') : 1e-20 : 0.04312470425968669 : 1.001 : False : False :  Reals
#         (0.0, 'H2O') : 1e-20 : 0.10063270207399252 : 1.001 : False : False :  Reals
#          (0.0, 'N2') : 1e-20 :  0.7444701460972505 : 1.001 : False : False :  Reals
#          (0.0, 'O2') : 1e-20 : 0.11177244756907036 : 1.001 : False : False :  Reals
#     _temperature_gas_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_out[...].component('temperature')
#         Key : Lower  : Value  : Upper : Fixed : Stale : Domain
#         0.0 : 2.7315 : 873.15 :  2000 :  True :  True : NonNegativeReals
#     _pressure_gas_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.gas_out[...].component('pressure')
#         Key : Lower : Value              : Upper              : Fixed : Stale : Domain
#         0.0 :   0.5 : 1000.0000000000001 : 1000.0000000000001 : False : False : NonNegativeReals
#     _flow_mol_comp_solid_inlet_ref : Size=11, Index=fs.roaster._flow_mol_comp_solid_inlet_ref_index, ReferenceTo=fs.roaster.solid_in[...].component('flow_mol_comp')[...]
#         Key                    : Lower                 : Value               : Upper : Fixed : Stale : Domain
#         (0.0, 'Al2(C2O4)3(s)') : 9.999999999999999e-18 :   6.972630100251837 :  None : False : False :  Reals
#         (0.0, 'Ce2(C2O4)3(s)') : 9.999999999999999e-18 :  6.3716886248711795 :  None : False : False :  Reals
#         (0.0, 'Dy2(C2O4)3(s)') : 9.999999999999999e-18 : 0.06319495921039599 :  None : False : False :  Reals
#         (0.0, 'Fe2(C2O4)3(s)') : 9.999999999999999e-18 :    9.20387979425454 :  None : False : False :  Reals
#         (0.0, 'Gd2(C2O4)3(s)') : 9.999999999999999e-18 : 0.29969539736223544 :  None : False : False :  Reals
#         (0.0, 'La2(C2O4)3(s)') : 9.999999999999999e-18 :  0.9743962114730162 :  None : False : False :  Reals
#         (0.0, 'Nd2(C2O4)3(s)') : 9.999999999999999e-18 :  1.4511901533448204 :  None : False : False :  Reals
#         (0.0, 'Pr2(C2O4)3(s)') : 9.999999999999999e-18 :  0.3804748263379557 :  None : False : False :  Reals
#         (0.0, 'Sc2(C2O4)3(s)') : 9.999999999999999e-18 :  124.87403096780555 :  None : False : False :  Reals
#         (0.0, 'Sm2(C2O4)3(s)') : 9.999999999999999e-18 : 0.14093422343887213 :  None : False : False :  Reals
#          (0.0, 'Y2(C2O4)3(s)') : 9.999999999999999e-18 : 0.28062636500168736 :  None : False : False :  Reals
#     _temperature_solid_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.roaster.solid_in[...].component('temperature')
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 2.9814999701859093 :  None : False : False :  Reals
#     heat_duty : heat duty added to the reactor
#         Size=1, Index=fs._time, Units=W
#         Key : Lower : Value             : Upper : Fixed : Stale : Domain
#         0.0 :  None : -562230307563.756 :  None : False : False :  Reals
#     deltaP : pressure drop from inlet to outlet
#         Size=1, Index=fs._time, Units=Pa
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :     0 :  None :  True :  True :  Reals
#     flow_mol_comp_feed : mole flow rate of oxalate in solid feed stream
#         Size=11, Index=fs.roaster.flow_mol_comp_feed_index, Units=mol/s
#         Key         : Lower : Value                  : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None :  1.936841694514399e-06 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None : 1.7699135069086608e-06 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None : 1.7554155336221195e-08 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None : 2.5566332761818167e-06 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None :  8.324872148950992e-08 :  None : False : False :  Reals
#         (0.0, 'La') :  None : 2.7066561429806015e-07 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None : 4.0310837592911684e-07 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None : 1.0568745176054333e-07 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None :  3.468723082439043e-05 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None : 3.9148395399686794e-08 :  None : False : False :  Reals
#          (0.0, 'Y') :  None :  7.795176805602436e-08 :  None : False : False :  Reals
#     flow_mol_moist_feed : mole flow rate of liquid water in solid feed stream
#         Size=1, Index=fs._time, Units=mol/s
#         Key : Lower : Value                : Upper : Fixed : Stale : Domain
#         0.0 :  None : 0.000791898980862421 :  None : False : False :  Reals
#     frac_comp_recovery : fraction of oxide recovery
#         Size=11, Index=fs.roaster.frac_comp_recovery_index
#         Key         : Lower : Value              : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None : 0.9499999999979889 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None : 0.9500000000010783 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None : 0.9499999999999998 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None : 0.9499999999962059 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None :  0.949999999999999 :  None : False : False :  Reals
#         (0.0, 'La') :  None : 0.9499999999999691 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None : 0.9499999999999603 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None :  0.949999999999997 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None : 0.9499999995251545 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None : 0.9499999999999996 :  None : False : False :  Reals
#          (0.0, 'Y') :  None : 0.9499999999999984 :  None : False : False :  Reals
#     flow_mol_comp_product : mole flow rate of oxide in product stream
#         Size=11, Index=fs.roaster.flow_mol_comp_product_index, Units=mol/s
#         Key         : Lower : Value                  : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None :  1.839999609784784e-06 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None : 1.6814178315651363e-06 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None : 1.6676447569410133e-08 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None :  2.428801612363026e-06 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None :  7.908628541503435e-08 :  None : False : False :  Reals
#         (0.0, 'La') :  None :  2.571323335831488e-07 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None : 3.8295295713264505e-07 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None : 1.0040307917251583e-07 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None : 3.2952869266699826e-05 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None :  3.719097562970244e-08 :  None : False : False :  Reals
#          (0.0, 'Y') :  None :  7.405417965322302e-08 :  None : False : False :  Reals
#     flow_mol_comp_dust : mole flow rate of oxide in dust stream
#         Size=11, Index=fs.roaster.flow_mol_comp_dust_index, Units=mol/s
#         Key         : Lower : Value                  : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None :   9.68420847296151e-08 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None :  8.849567534352442e-08 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None :  8.777077668110617e-10 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None : 1.2783166381879096e-07 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None :  4.162436074475585e-09 :  None : False : False :  Reals
#         (0.0, 'La') :  None :  1.353328071491136e-08 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None : 2.0155418796471822e-08 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None :  5.284372588027492e-09 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None : 1.7343615576905992e-06 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None : 1.9574197699843535e-09 :  None : False : False :  Reals
#          (0.0, 'Y') :  None : 3.8975884028013455e-09 :  None : False : False :  Reals
#     enth_mol_comp_feed : molar enthalpy of individual species of solid oxalate feed
#         Size=11, Index=fs.roaster.enth_mol_comp_feed_index, Units=J/mol
#         Key         : Lower : Value               : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None : -3397000.0001364024 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None :  -6782000.000136402 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None :  -6350044.000136402 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None :  -6782000.000136402 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None :  -6350044.000136402 :  None : False : False :  Reals
#         (0.0, 'La') :  None :  -5916176.000136402 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None :  -6782000.000136402 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None :  -5920000.000136402 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None :  -6350044.000136402 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None :  -6350044.000136402 :  None : False : False :  Reals
#          (0.0, 'Y') :  None :  -6350044.000136402 :  None : False : False :  Reals
#     enth_mol_comp_product : molar enthalpy of individual species of solid oxide product
#         Size=11, Index=fs.roaster.enth_mol_comp_product_index, Units=J/mol
#         Key         : Lower : Value              : Upper : Fixed : Stale : Domain
#         (0.0, 'Al') :  None : 137102596.89620838 :  None : False : False :  Reals
#         (0.0, 'Ce') :  None : 140818736.35747486 :  None : False : False :  Reals
#         (0.0, 'Dy') :  None : 136975731.14620838 :  None : False : False :  Reals
#         (0.0, 'Fe') :  None : 137952096.89620838 :  None : False : False :  Reals
#         (0.0, 'Gd') :  None : 136975731.14620838 :  None : False : False :  Reals
#         (0.0, 'La') :  None : 107123975.15140742 :  None : False : False :  Reals
#         (0.0, 'Nd') :  None : 160960155.12178662 :  None : False : False :  Reals
#         (0.0, 'Pr') :  None :  139000057.9541646 :  None : False : False :  Reals
#         (0.0, 'Sc') :  None : 136868730.89620838 :  None : False : False :  Reals
#         (0.0, 'Sm') :  None : 136975731.14620838 :  None : False : False :  Reals
#          (0.0, 'Y') :  None : 136844796.89620838 :  None : False : False :  Reals
#
#   Objectives:
#     None
#
#   Constraints:
#     flow_mol_comp_feed_eqn : Size=11
#         Key         : Lower : Body                   : Upper
#         (0.0, 'Al') :   0.0 :                    0.0 :   0.0
#         (0.0, 'Ce') :   0.0 :                    0.0 :   0.0
#         (0.0, 'Dy') :   0.0 :  8.933550615572699e-23 :   0.0
#         (0.0, 'Fe') :   0.0 :                    0.0 :   0.0
#         (0.0, 'Gd') :   0.0 :  7.940933880509066e-23 :   0.0
#         (0.0, 'La') :   0.0 : 1.0587911840678754e-22 :   0.0
#         (0.0, 'Nd') :   0.0 : 1.0587911840678754e-22 :   0.0
#         (0.0, 'Pr') :   0.0 :   9.26442286059391e-23 :   0.0
#         (0.0, 'Sc') :   0.0 :  6.776263578034403e-21 :   0.0
#         (0.0, 'Sm') :   0.0 :   9.26442286059391e-23 :   0.0
#          (0.0, 'Y') :   0.0 : 1.0587911840678754e-22 :   0.0
#     flow_mol_outlet_eqn : Size=4
#         Key          : Lower : Body                    : Upper
#         (0.0, 'CO2') :   0.0 :   5.551115123125783e-17 :   0.0
#         (0.0, 'H2O') :   0.0 :                     0.0 :   0.0
#          (0.0, 'N2') :   0.0 :  -8.881784197001252e-16 :   0.0
#          (0.0, 'O2') :   0.0 : -1.1102230246251565e-16 :   0.0
#     flow_mol_product : Size=11
#         Key         : Lower : Body                    : Upper
#         (0.0, 'Al') :   0.0 :   2.117582368135751e-22 :   0.0
#         (0.0, 'Ce') :   0.0 :                     0.0 :   0.0
#         (0.0, 'Dy') :   0.0 :                     0.0 :   0.0
#         (0.0, 'Fe') :   0.0 :                     0.0 :   0.0
#         (0.0, 'Gd') :   0.0 :  1.3234889800848443e-23 :   0.0
#         (0.0, 'La') :   0.0 :                     0.0 :   0.0
#         (0.0, 'Nd') :   0.0 :   5.293955920339377e-23 :   0.0
#         (0.0, 'Pr') :   0.0 : -1.3234889800848443e-23 :   0.0
#         (0.0, 'Sc') :   0.0 :  -6.776263578034403e-21 :   0.0
#         (0.0, 'Sm') :   0.0 :                     0.0 :   0.0
#          (0.0, 'Y') :   0.0 :                     0.0 :   0.0
#     flow_mol_dust : Size=11
#         Key         : Lower : Body                    : Upper
#         (0.0, 'Al') :   0.0 :  -3.970466940254533e-23 :   0.0
#         (0.0, 'Ce') :   0.0 : -1.0587911840678754e-22 :   0.0
#         (0.0, 'Dy') :   0.0 :  -7.237830359838992e-25 :   0.0
#         (0.0, 'Fe') :   0.0 :  -5.293955920339377e-23 :   0.0
#         (0.0, 'Gd') :   0.0 :  1.6543612251060553e-24 :   0.0
#         (0.0, 'La') :   0.0 : -1.3234889800848443e-23 :   0.0
#         (0.0, 'Nd') :   0.0 : -1.6543612251060553e-23 :   0.0
#         (0.0, 'Pr') :   0.0 :  4.1359030627651384e-24 :   0.0
#         (0.0, 'Sc') :   0.0 :   6.352747104407253e-22 :   0.0
#         (0.0, 'Sm') :   0.0 :  -8.271806125530277e-25 :   0.0
#          (0.0, 'Y') :   0.0 :   2.481541837659083e-24 :   0.0
#     enth_mol_comp_feed_eqn : Size=11
#         Key         : Lower : Body : Upper
#         (0.0, 'Al') :   0.0 :  0.0 :   0.0
#         (0.0, 'Ce') :   0.0 :  0.0 :   0.0
#         (0.0, 'Dy') :   0.0 :  0.0 :   0.0
#         (0.0, 'Fe') :   0.0 :  0.0 :   0.0
#         (0.0, 'Gd') :   0.0 :  0.0 :   0.0
#         (0.0, 'La') :   0.0 :  0.0 :   0.0
#         (0.0, 'Nd') :   0.0 :  0.0 :   0.0
#         (0.0, 'Pr') :   0.0 :  0.0 :   0.0
#         (0.0, 'Sc') :   0.0 :  0.0 :   0.0
#         (0.0, 'Sm') :   0.0 :  0.0 :   0.0
#          (0.0, 'Y') :   0.0 :  0.0 :   0.0
#     enth_mol_comp_product_eqn : Size=11
#         Key         : Lower : Body : Upper
#         (0.0, 'Al') :   0.0 :  0.0 :   0.0
#         (0.0, 'Ce') :   0.0 :  0.0 :   0.0
#         (0.0, 'Dy') :   0.0 :  0.0 :   0.0
#         (0.0, 'Fe') :   0.0 :  0.0 :   0.0
#         (0.0, 'Gd') :   0.0 :  0.0 :   0.0
#         (0.0, 'La') :   0.0 :  0.0 :   0.0
#         (0.0, 'Nd') :   0.0 :  0.0 :   0.0
#         (0.0, 'Pr') :   0.0 :  0.0 :   0.0
#         (0.0, 'Sc') :   0.0 :  0.0 :   0.0
#         (0.0, 'Sm') :   0.0 :  0.0 :   0.0
#          (0.0, 'Y') :   0.0 :  0.0 :   0.0
#     energy_balance_eqn : Size=1
#         Key : Lower : Body            : Upper
#         0.0 :   0.0 : -0.000244140625 :   0.0
#     momentum_balance_eqn : Size=1
#         Key : Lower : Body                : Upper
#         0.0 :   0.0 : -10032499999.999998 :   0.0
#
#   Blocks:
#     Block fs.roaster.gas_in[0.0]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value               : Upper : Fixed : Stale : Domain
#             None :   0.0 : 0.00781002309039114 :  50.0 : False : False : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=4, Index=fs.prop_gas.component_list, Units=dimensionless
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             CO2 : 1e-20 : 0.0431 : 1.001 :  True :  True :  Reals
#             H2O : 1e-20 : 0.1005 : 1.001 :  True :  True :  Reals
#              N2 : 1e-20 : 0.7446 : 1.001 :  True :  True :  Reals
#              O2 : 1e-20 : 0.1118 : 1.001 :  True :  True :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower : Value  : Upper     : Fixed : Stale : Domain
#             None :   0.5 : 101325 : 1000000.0 :  True :  True : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#             None : 2.7315 :  1330 :  2000 :  True :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=1, Index=fs.prop_gas.phase_list, Units=mol/s
#             Key : Lower : Value               : Upper : Fixed : Stale : Domain
#             Vap :   0.0 : 0.00781002309039114 :  50.0 : False : False : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=4, Index=fs.prop_gas._phase_component_set, Units=dimensionless
#             Key            : Lower : Value  : Upper : Fixed : Stale : Domain
#             ('Vap', 'CO2') : 1e-20 : 0.0431 : 1.001 : False : False :  Reals
#             ('Vap', 'H2O') : 1e-20 : 0.1005 : 1.001 : False : False :  Reals
#              ('Vap', 'N2') : 1e-20 : 0.7446 : 1.001 : False : False :  Reals
#              ('Vap', 'O2') : 1e-20 : 0.1118 : 1.001 : False : False :  Reals
#         phase_frac : Phase fractions
#             Size=1, Index=fs.prop_gas.phase_list, Units=dimensionless
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             Vap :   0.0 :   1.0 :  None : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         total_flow_balance : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         component_flow_balances : Size=4
#             Key : Lower : Body : Upper
#             CO2 :   0.0 :  0.0 :   0.0
#             H2O :   0.0 :  0.0 :   0.0
#              N2 :   0.0 :  0.0 :   0.0
#              O2 :   0.0 :  0.0 :   0.0
#         phase_fraction_constraint : Size=1
#             Key : Lower : Body : Upper
#             Vap :   1.0 :  1.0 :   1.0
#     Block fs.roaster.gas_out[0.0]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value                : Upper : Fixed : Stale : Domain
#             None :   0.0 : 0.007811385350495414 :  50.0 : False : False : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=4, Index=fs.prop_gas.component_list, Units=dimensionless
#             Key : Lower : Value               : Upper : Fixed : Stale : Domain
#             CO2 : 1e-20 : 0.04312470425968669 : 1.001 : False : False :  Reals
#             H2O : 1e-20 : 0.10063270207399252 : 1.001 : False : False :  Reals
#              N2 : 1e-20 :  0.7444701460972505 : 1.001 : False : False :  Reals
#              O2 : 1e-20 : 0.11177244756907036 : 1.001 : False : False :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower : Value              : Upper              : Fixed : Stale : Domain
#             None :   0.5 : 1000.0000000000001 : 1000.0000000000001 : False : False : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value  : Upper : Fixed : Stale : Domain
#             None : 2.7315 : 873.15 :  2000 :  True :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=1, Index=fs.prop_gas.phase_list, Units=mol/s
#             Key : Lower : Value                : Upper : Fixed : Stale : Domain
#             Vap :   0.0 : 0.007811385350495414 :  50.0 : False : False : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=4, Index=fs.prop_gas._phase_component_set, Units=dimensionless
#             Key            : Lower : Value               : Upper : Fixed : Stale : Domain
#             ('Vap', 'CO2') : 1e-20 : 0.04312470425968669 : 1.001 : False : False :  Reals
#             ('Vap', 'H2O') : 1e-20 : 0.10063270207399252 : 1.001 : False : False :  Reals
#              ('Vap', 'N2') : 1e-20 :  0.7444701460972505 : 1.001 : False : False :  Reals
#              ('Vap', 'O2') : 1e-20 : 0.11177244756907036 : 1.001 : False : False :  Reals
#         phase_frac : Phase fractions
#             Size=1, Index=fs.prop_gas.phase_list, Units=dimensionless
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             Vap :   0.0 :   1.0 :  None : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         sum_mole_frac_out : Size=1
#             Key  : Lower : Body : Upper
#             None :   1.0 :  1.0 :   1.0
#         total_flow_balance : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         component_flow_balances : Size=4
#             Key : Lower : Body : Upper
#             CO2 :   0.0 :  0.0 :   0.0
#             H2O :   0.0 :  0.0 :   0.0
#              N2 :   0.0 :  0.0 :   0.0
#              O2 :   0.0 :  0.0 :   0.0
#         phase_fraction_constraint : Size=1
#             Key : Lower : Body : Upper
#             Vap :   1.0 :  1.0 :   1.0
#     Block fs.roaster.solid_in[0.0]
#
#       Variables:
#         temperature : Temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#             None :     0 : 2.9814999701859093 :  None : False : False :  Reals
#         flow_mol_comp : Size=11, Index=fs.roaster.solid_in[0.0].flow_mol_comp_index, Units=mol/h
#             Key           : Lower                 : Value               : Upper : Fixed : Stale : Domain
#             Al2(C2O4)3(s) : 9.999999999999999e-18 :   6.972630100251837 :  None : False : False :  Reals
#             Ce2(C2O4)3(s) : 9.999999999999999e-18 :  6.3716886248711795 :  None : False : False :  Reals
#             Dy2(C2O4)3(s) : 9.999999999999999e-18 : 0.06319495921039599 :  None : False : False :  Reals
#             Fe2(C2O4)3(s) : 9.999999999999999e-18 :    9.20387979425454 :  None : False : False :  Reals
#             Gd2(C2O4)3(s) : 9.999999999999999e-18 : 0.29969539736223544 :  None : False : False :  Reals
#             La2(C2O4)3(s) : 9.999999999999999e-18 :  0.9743962114730162 :  None : False : False :  Reals
#             Nd2(C2O4)3(s) : 9.999999999999999e-18 :  1.4511901533448204 :  None : False : False :  Reals
#             Pr2(C2O4)3(s) : 9.999999999999999e-18 :  0.3804748263379557 :  None : False : False :  Reals
#             Sc2(C2O4)3(s) : 9.999999999999999e-18 :  124.87403096780555 :  None : False : False :  Reals
#             Sm2(C2O4)3(s) : 9.999999999999999e-18 : 0.14093422343887213 :  None : False : False :  Reals
#              Y2(C2O4)3(s) : 9.999999999999999e-18 : 0.28062636500168736 :  None : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
